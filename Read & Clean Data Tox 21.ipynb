# %%
import pandas 
from rdkit.Chem import PandasTools
import pandas as pd
import os
from rdkit import RDConfig

# %%
#Read Data from Data repository \

file = "D:\\projects_git\\2020_toxicity\\data\\tox21_10k_data_all.sdf"

# %%
datasdf = os.path.join(RDConfig.RDDataDir,file)
moldf = PandasTools.LoadSDF(datasdf,smilesName='SMILES',molColName='Molecule',
           includeFingerprints=True)

# %%
moldf
# Out:
#              Formula                                                 FW  \
# 0         C27H25ClN6               468.9806 (35.4535+224.2805+209.2465)
# 1      C20H6Br4Na2O5                691.8542 (645.8757+22.9892+22.9892)
# 2         C47H83NO17                        934.1584 (916.1205+18.0379)
# 3        C52H54N4O12  927.0048 (329.4575+89.0275+89.0275+329.4575+90...
# 4       C66H87N17O14                      1342.5025 (1282.4505+60.0520)
# ...              ...                                                ...
# 11759      C7H10N2OS                                           170.2321
# 11760        C3H6N2S                                           102.1581
# 11761        C3H6N2S                                           102.1581
# 11762    C10H14NO5PS                                           291.2606
# 11763     C15H26O6S3                                           398.5583
#
#       DSSTox_CID SR-HSE               ID  \
# 0          25848      0  NCGC00178831-03
# ...
